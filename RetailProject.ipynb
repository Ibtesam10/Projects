# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import cycle

pd.set_option('max_columns', 90)
pd.set_option('max_rows', 90)
plt.style.use('bmh')
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']
color_cycle = cycle(plt.rcParams['axes.prop_cycle'].by_key()['color'])

# %% [markdown]
# ## 1. Import the data

# %%
test_data=pd.read_csv("test.csv")
train_data=pd.read_csv("train.csv")

# %%
train_data.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID        state state_ab  \
# 0  267822      NaN       140        53       36     New York       NY
# 1  246444      NaN       140       141       18      Indiana       IN
# 2  245683      NaN       140        63       18      Indiana       IN
# 3  279653      NaN       140       127       72  Puerto Rico       PR
# 4  247218      NaN       140       161       20       Kansas       KS
#
#          city           place   type primary  zip_code  area_code        lat  \
# 0    Hamilton        Hamilton   City   tract     13346        315  42.840812
# 1  South Bend        Roseland   City   tract     46616        574  41.701441
# 2    Danville        Danville   City   tract     46122        317  39.792202
# 3    San Juan        Guaynabo  Urban   tract       927        787  18.396103
# 4   Manhattan  Manhattan City   City   tract     66502        785  39.195573
#
#          lng        ALand   AWater   pop  male_pop  female_pop  rent_mean  \
# ...

# %%
test_data.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0  255504      NaN       140       163       26      Michigan       MI
# 1  252676      NaN       140         1       23         Maine       ME
# 2  276314      NaN       140        15       42  Pennsylvania       PA
# 3  248614      NaN       140       231       21      Kentucky       KY
# 4  286865      NaN       140       355       48         Texas       TX
#
#              city                  place     type primary  zip_code  \
# 0         Detroit  Dearborn Heights City      CDP   tract     48239
# 1          Auburn            Auburn City     City   tract      4210
# 2       Pine City              Millerton  Borough   tract     14871
# 3      Monticello        Monticello City     City   tract     42633
# 4  Corpus Christi                  Edroy     Town   tract     78410
#
#    area_code        lat        lng      ALand   AWater   pop  male_pop  \
# ...

# %% [markdown]
# ## 2. Find the primary key

# %% [markdown]
# UID is the primary key, as it is unique reference key.

# %% [markdown]
# ## 3.Gauge the fill rate of the variables and devise plans for missing value treatment. Please explain explicitly the reason for the treatment chosen for each variable.

# %% [markdown]
# First lets perform operations on the training data, then perform on the test data.

# %%
train_data.dtypes
# Out:
# UID                              int64
# BLOCKID                        float64
# SUMLEVEL                         int64
# COUNTYID                         int64
# STATEID                          int64
# state                           object
# state_ab                        object
# city                            object
# place                           object
# type                            object
# primary                         object
# zip_code                         int64
# area_code                        int64
# lat                            float64
# lng                            float64
# ALand                          float64
# AWater                           int64
# pop                              int64
# male_pop                         int64
# female_pop                       int64
# rent_mean                      float64
# rent_median                    float64
# rent_stdev                     float64
# rent_sample_weight             float64
# ...

# %%
train_data.columns
# Out:
# Index(['UID', 'BLOCKID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state',
#        'state_ab', 'city', 'place', 'type', 'primary', 'zip_code', 'area_code',
#        'lat', 'lng', 'ALand', 'AWater', 'pop', 'male_pop', 'female_pop',
#        'rent_mean', 'rent_median', 'rent_stdev', 'rent_sample_weight',
#        'rent_samples', 'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25',
#        'rent_gt_30', 'rent_gt_35', 'rent_gt_40', 'rent_gt_50',
#        'universe_samples', 'used_samples', 'hi_mean', 'hi_median', 'hi_stdev',
#        'hi_sample_weight', 'hi_samples', 'family_mean', 'family_median',
#        'family_stdev', 'family_sample_weight', 'family_samples',
#        'hc_mortgage_mean', 'hc_mortgage_median', 'hc_mortgage_stdev',
#        'hc_mortgage_sample_weight', 'hc_mortgage_samples', 'hc_mean',
#        'hc_median', 'hc_stdev', 'hc_samples', 'hc_sample_weight',
#        'home_equity_second_mortgage', 'second_mortgage', 'home_equity', 'debt',
# ...

# %%
A=pd.DataFrame(train_data.columns)
A
# Out:
#                               0
# 0                           UID
# 1                       BLOCKID
# 2                      SUMLEVEL
# 3                      COUNTYID
# 4                       STATEID
# 5                         state
# 6                      state_ab
# 7                          city
# 8                         place
# 9                          type
# 10                      primary
# 11                     zip_code
# 12                    area_code
# 13                          lat
# 14                          lng
# 15                        ALand
# 16                       AWater
# 17                          pop
# 18                     male_pop
# 19                   female_pop
# 20                    rent_mean
# 21                  rent_median
# 22                   rent_stdev
# 23           rent_sample_weight
# 24                 rent_samples
# 25                   rent_gt_10
# 26                   rent_gt_15
# 27                   rent_gt_20
# ...

# %%
train_data.shape
# Out:
# (27321, 80)

# %%
train_data.isnull().sum()
# Out:
# UID                                0
# BLOCKID                        27321
# SUMLEVEL                           0
# COUNTYID                           0
# STATEID                            0
# state                              0
# state_ab                           0
# city                               0
# place                              0
# type                               0
# primary                            0
# zip_code                           0
# area_code                          0
# lat                                0
# lng                                0
# ALand                              0
# AWater                             0
# pop                                0
# male_pop                           0
# female_pop                         0
# rent_mean                        314
# rent_median                      314
# rent_stdev                       314
# rent_sample_weight               314
# rent_samples                     314
# ...

# %%
train_data.duplicated().sum()
# Out:
# 160

# %% [markdown]
# 1.There are 80 columns with 27321 records in the training data </br>
# 2.There are null values in the columns</br>
# 3.There are 160 duplicated records</br>
# 4.The data types range from int to float

# %% [markdown]
# ## Treating Missing Values

# %% [markdown]
# ## Number of columns with missing values

# %%
len(train_data.columns[train_data.isnull().sum(axis=0 )> 0])
# Out:
# 59

# %% [markdown]
# There are 59 columns with missing values.

# %% [markdown]
# ## percentage of missings values in each column

# %%
percent_missing = train_data.isnull().sum() * 100 / len(train_data)
missing_value_df = pd.DataFrame({'column_name': train_data.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df
# Out:
#                                              column_name  percent_missing
# UID                                                  UID         0.000000
# BLOCKID                                          BLOCKID       100.000000
# SUMLEVEL                                        SUMLEVEL         0.000000
# COUNTYID                                        COUNTYID         0.000000
# STATEID                                          STATEID         0.000000
# state                                              state         0.000000
# state_ab                                        state_ab         0.000000
# city                                                city         0.000000
# place                                              place         0.000000
# type                                                type         0.000000
# primary                                          primary         0.000000
# zip_code                                        zip_code         0.000000
# ...

# %% [markdown]
# We can delete the column "BLOCK ID" as it has all null values

# %%
train_data.drop('BLOCKID', axis=1 , inplace=True)

# %% [markdown]
# ## Calculate the overall percentage of missing data in the dataset

# %%
Missing_values=train_data[train_data.isnull().any(axis=1)]
Missing_values
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 51     223593       140        19        4        Arizona       AZ
# 94     233040       140       101        8       Colorado       CO
# 153    263292       140        13       34     New Jersey       NJ
# 302    267158       140        47       36       New York       NY
# 340    292484       140        25       55      Wisconsin       WI
# ...       ...       ...       ...      ...            ...      ...
# 27127  266321       140         5       36       New York       NY
# 27175  235725       140        57       12        Florida       FL
# 27176  247777       140        61       21       Kentucky       KY
# 27216  266166       140         5       36       New York       NY
# 27240  251078       140        25       25  Massachusetts       MA
#
#               city              place  type primary  zip_code  area_code  \
# 51          Tucson         Littletown   CDP   tract     85734        520
# ...

# %%
Missing_values.shape
# Out:
# (736, 79)

# %%
train_data.shape
# Out:
# (27321, 79)

# %%
missing_percentage= (736/27321) * 100
missing_percentage
# Out:
# 2.693898466381172

# %% [markdown]
# The overall missing data in the dataset is 2.69 which is negligable, therefore the missing values can be dropped.

# %% [markdown]
# ## Dropping NULL/NAN values

# %%
train_data.dropna()
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0      267822       140        53       36      New York       NY
# 1      246444       140       141       18       Indiana       IN
# 2      245683       140        63       18       Indiana       IN
# 3      279653       140       127       72   Puerto Rico       PR
# 4      247218       140       161       20        Kansas       KS
# ...       ...       ...       ...      ...           ...      ...
# 27316  279212       140        43       72   Puerto Rico       PR
# 27317  277856       140        91       42  Pennsylvania       PA
# 27318  233000       140        87        8      Colorado       CO
# 27319  287425       140       439       48         Texas       TX
# 27320  265371       140         3       32        Nevada       NV
#
#               city             place     type primary  zip_code  area_code  \
# 0         Hamilton          Hamilton     City   tract     13346        315
# ...

# %%
train_data.duplicated().sum()
# Out:
# 160

# %%
train_data.drop_duplicates(inplace=True)

# %%
train_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Final dataset size

# %%
train_data.shape
# Out:
# (27161, 79)

# %% [markdown]
# ## Same will be performed on the test data

# %%
test_data.isnull().sum()
# Out:
# UID                                0
# BLOCKID                        11709
# SUMLEVEL                           0
# COUNTYID                           0
# STATEID                            0
# state                              0
# state_ab                           0
# city                               0
# place                              0
# type                               0
# primary                            0
# zip_code                           0
# area_code                          0
# lat                                0
# lng                                0
# ALand                              0
# AWater                             0
# pop                                0
# male_pop                           0
# female_pop                         0
# rent_mean                        148
# rent_median                      148
# rent_stdev                       148
# rent_sample_weight               148
# rent_samples                     148
# ...

# %%
percent_missing1 = test_data.isnull().sum() * 100 / len(test_data)
missing_value_df1 = pd.DataFrame({'column_name': test_data.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df1
# Out:
#                                              column_name  percent_missing
# UID                                                  UID         0.000000
# BLOCKID                                          BLOCKID       100.000000
# SUMLEVEL                                        SUMLEVEL         0.000000
# COUNTYID                                        COUNTYID         0.000000
# STATEID                                          STATEID         0.000000
# state                                              state         0.000000
# state_ab                                        state_ab         0.000000
# city                                                city         0.000000
# place                                              place         0.000000
# type                                                type         0.000000
# primary                                          primary         0.000000
# zip_code                                        zip_code         0.000000
# ...

# %%
test_data.drop('BLOCKID', axis=1 , inplace=True)

# %%
Missing_values1=test_data[test_data.isnull().any(axis=1)]
Missing_values1
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 17     265339       140         3       32         Nevada       NV
# 27     287596       140       451       48          Texas       TX
# 44     250903       140        25       25  Massachusetts       MA
# 54     287557       140       441       48          Texas       TX
# 70     247510       140       209       20         Kansas       KS
# ...       ...       ...       ...      ...            ...      ...
# 11543  267675       140        47       36       New York       NY
# 11554  288512       140        35       49           Utah       UT
# 11561  275715       140         3       42   Pennsylvania       PA
# 11636  276588       140        27       42   Pennsylvania       PA
# 11675  266164       140         5       36       New York       NY
#
#                  city                place     type primary  zip_code  \
# 17          Las Vegas           Winchester     City   tract     89119
# ...

# %%
test_data.shape
# Out:
# (11709, 79)

# %%
missing_percentage= (354/11709) * 100
missing_percentage
# Out:
# 3.0233153984114787

# %%
test_data.dropna()
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID          state state_ab  \
# 0      255504       140       163       26       Michigan       MI
# 1      252676       140         1       23          Maine       ME
# 2      276314       140        15       42   Pennsylvania       PA
# 3      248614       140       231       21       Kentucky       KY
# 4      286865       140       355       48          Texas       TX
# ...       ...       ...       ...      ...            ...      ...
# 11704  238088       140       105       12        Florida       FL
# 11705  242811       140        31       17       Illinois       IL
# 11706  250127       140         9       25  Massachusetts       MA
# 11707  241096       140        27       19           Iowa       IA
# 11708  287763       140       453       48          Texas       TX
#
#                  city                  place     type primary  zip_code  \
# 0             Detroit  Dearborn Heights City      CDP   tract     48239
# ...

# %%
test_data.drop_duplicates(inplace=True)

# %%
test_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## TEST DATA FINAL SIZE

# %%
test_data.shape
# Out:
# (11677, 79)

# %% [markdown]
# ### Perform EDA and come out with insights into population density and age. You may require deriving new fields (Make sure to weight averages for accurate measurements):
# ### •	Population density (hint-use ‘pop’ and ‘Aland’ to calculate)</br>
# ### •	median age (hint-use the variables ‘male_age_median’, ‘female_age_median’, ‘male_pop’, ‘female_pop’)</br>
# ### Visualize the findings using appropriate chart type.

# %%
df= train_data[['state', 'city', 'place','type','ALand', 'pop', 'male_age_median', 'female_age_median', 'male_pop', 'female_pop']]
df.head()
# Out:
#          state        city           place   type        ALand   pop  \
# 0     New York    Hamilton        Hamilton   City  202183361.0  5230
# 1      Indiana  South Bend        Roseland   City    1560828.0  2633
# 2      Indiana    Danville        Danville   City   69561595.0  6881
# 3  Puerto Rico    San Juan        Guaynabo  Urban    1105793.0  2700
# 4       Kansas   Manhattan  Manhattan City   City    2554403.0  5637
#
#    male_age_median  female_age_median  male_pop  female_pop
# 0         44.00000           45.33333      2612        2618
# 1         32.00000           37.58333      1349        1284
# 2         40.83333           42.83333      3643        3238
# 3         48.91667           50.58333      1141        1559
# 4         22.41667           21.58333      2586        3051

# %%
df.shape
# Out:
# (27161, 10)

# %% [markdown]
# ## Population density is total population by total area of land; Therefore we will use total population as pop and total area of land as ALand

# %%
pd.options.mode.chained_assignment = None

# %%
df['p_density'] = df['pop'] / df['ALand']

# %% [markdown]
# ## Median age will be average of of median age of male and median age of female.

# %%
df['median_age'] = (df['male_age_median']+ df['female_age_median']) / 2

# %%
df.head()
# Out:
#          state        city           place   type        ALand   pop  \
# 0     New York    Hamilton        Hamilton   City  202183361.0  5230
# 1      Indiana  South Bend        Roseland   City    1560828.0  2633
# 2      Indiana    Danville        Danville   City   69561595.0  6881
# 3  Puerto Rico    San Juan        Guaynabo  Urban    1105793.0  2700
# 4       Kansas   Manhattan  Manhattan City   City    2554403.0  5637
#
#    male_age_median  female_age_median  male_pop  female_pop  p_density  \
# 0         44.00000           45.33333      2612        2618   0.000026
# 1         32.00000           37.58333      1349        1284   0.001687
# 2         40.83333           42.83333      3643        3238   0.000099
# 3         48.91667           50.58333      1141        1559   0.002442
# 4         22.41667           21.58333      2586        3051   0.002207
#
#    median_age
# 0   44.666665
# 1   34.791665
# 2   41.833330
# 3   49.750000
# 4   22.000000

# %% [markdown]
# Load the df dataset in the excel sheet to perform visualisations.

# %%
df.to_excel('A.xlsx')

# %%
#--> USED POWERBI For visualisations

# %% [markdown]
# ### Create bins for population into a new variable by selecting appropriate class interval so that the no of categories(bins) don’t exceed 5 for the ease of analysis. Analyze the married, separated and divorced population for these population brackets. Visualize using appropriate chart type.

# %%
train_data.head()
# Out:
#       UID  SUMLEVEL  COUNTYID  STATEID        state state_ab        city  \
# 0  267822       140        53       36     New York       NY    Hamilton
# 1  246444       140       141       18      Indiana       IN  South Bend
# 2  245683       140        63       18      Indiana       IN    Danville
# 3  279653       140       127       72  Puerto Rico       PR    San Juan
# 4  247218       140       161       20       Kansas       KS   Manhattan
#
#             place   type primary  zip_code  area_code        lat        lng  \
# 0        Hamilton   City   tract     13346        315  42.840812 -75.501524
# 1        Roseland   City   tract     46616        574  41.701441 -86.266614
# 2        Danville   City   tract     46122        317  39.792202 -86.515246
# 3        Guaynabo  Urban   tract       927        787  18.396103 -66.104169
# 4  Manhattan City   City   tract     66502        785  39.195573 -96.569366
#
# ...

# %% [markdown]
# ## lets find the maximum value of male mean age and female mean age in the dataset.

# %%
train_data["male_age_mean"].max()
# Out:
# 77.75992

# %%
train_data["female_age_mean"].max()
# Out:
# 79.83739

# %% [markdown]
# ## lets find the minimum value of male mean age and female mean age in the dataset.

# %%
train_data["male_age_mean"].min()
# Out:
# 12.14583

# %%
train_data["female_age_mean"].min()
# Out:
# 16.008329999999997

# %%
age_df = train_data[['state', 'city', 'place', 'pop', 'male_pop', 'female_pop', 'male_age_median', 'female_age_median', 'married', 'separated', 'divorced']]

# %% [markdown]
# ## THE BRACKETS :
#
# YOUNG YOUTH - <18 </br>
# YOUTH - 19 to 30  </br>
# ADULT - 30 to 55  </br>
# SENIOR - >55      </br>

# %%
bins = [0,18, 30, 55, 100]
labels = ['YOUNG YOUTH', 'YOUTH', ' ADULLT' , 'SENIOR']

# %%
age_df['male_population_bracket'] = pd.cut(age_df['male_age_median'], bins, labels = labels)

# %%
age_df['female_population_bracket'] = pd.cut(age_df['female_age_median'], bins, labels = labels)

# %%
age_df.head()
# Out:
#          state        city           place   pop  male_pop  female_pop  \
# 0     New York    Hamilton        Hamilton  5230      2612        2618
# 1      Indiana  South Bend        Roseland  2633      1349        1284
# 2      Indiana    Danville        Danville  6881      3643        3238
# 3  Puerto Rico    San Juan        Guaynabo  2700      1141        1559
# 4       Kansas   Manhattan  Manhattan City  5637      2586        3051
#
#    male_age_median  female_age_median  married  separated  divorced  \
# 0         44.00000           45.33333  0.57851    0.01240   0.08770
# 1         32.00000           37.58333  0.34886    0.01426   0.09030
# 2         40.83333           42.83333  0.64745    0.01607   0.10657
# 3         48.91667           50.58333  0.47257    0.02021   0.10106
# 4         22.41667           21.58333  0.12356    0.00000   0.03109
#
#   male_population_bracket female_population_bracket
# 0                   Adult                     Adult
# ...

# %% [markdown]
# Load the df dataset in the excel sheet to perform visualisations.

# %%
age_df.to_excel('B.xlsx')

# %%
#--> USED POWERBI For visualisations
